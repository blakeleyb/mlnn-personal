# %%
print "Hello World"
# Out:
#   File "C:\Users\blake\AppData\Local\Temp\ipykernel_14296\796388850.py", line 1
#     print "Hello World"
#           ^
# SyntaxError: Missing parentheses in call to 'print'. Did you mean print("Hello World")?

# %%
print("Hello World")
# Out:
# Hello World

# %%
s = 3
t = 2
s*t
# Out:
# 6

# %%
import numpy
import scipy
import matplotlib
import pandas
import statsmodels
import seaborn
import sklearn

# %%
print("numpy:", numpy.__version__)
print("scipy:", scipy.__version__)
print("matplotlib:", matplotlib.__version__)
print("statsmodels:", statsmodels.__version__)
print("pandas:", pandas.__version__)
print("seaborn:", seaborn.__version__)
print("sklearn:", sklearn.__version__)
# Out:
# numpy: 1.21.5
# scipy: 1.9.1
# matplotlib: 3.5.2
# statsmodels: 0.13.2
# pandas: 1.4.4
# seaborn: 0.11.2
# sklearn: 1.0.2

# %%
# %matplotlib inline

# %%
import matplotlib.pylab as plt

# %%
plt.scatter([3,2,5], [1,2,3])

# %%
g = 8

# %%
def hourly(annualwage):
    hourlywage = annualwage/(40*52)
    
    
    return hourlywage

# %%
hourly(50000)
# Out:
# 24.03846153846154

# %%
hourly(80000)
# Out:
# 38.46153846153846

# %%
g+t
# Out:
# 10

# %%
plt.plot([6,9,8], [1,4,7])

# %% [markdown]
# I've read the keyboard shortcuts (Help -> Keyboard Shortcuts)

# %%
989*157
# Out:
# 155273

# %%
a = 989+157
b = 5463-976543

a*b
# Out:
# -1112857680
